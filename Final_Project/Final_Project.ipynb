# %% [markdown]
# # CLASSIFICATION OF DOCUMENTS BY USING NAIVE BAYES

# %% [markdown]
# ### PROBLEM STATEMENT

# %% [markdown]
# To identify the class of the given test document by using training dataset.

# %% [markdown]
# ### ABSTRACT

# %% [markdown]
# This project is to identify the class of the document, based on the documents used for training. To be clear, few documents and the corresponding class of document will be given.  Now, by using Multinomial Naive Bayes algorithm given documents are analyzed. Navie Bayes uses the conditional probability of Bayes theorem.  When test document is given, multinomial algorithm analyzes every word in the text document in perspective to all classes and assigns a score. Finally, the class with more score is the class of the testing document.

# %% [markdown]
# ### ALGORITHM EXPLANATION

# %% [markdown]
# <pre>
# TRAINMULTINOMIALNB(C, D)
# 1 V ← EXTRACTVOCABULARY(D)
# 2 N ← COUNTDOCS(D)
# 3 for each c ∈ C
# 4 do Nc ← COUNTDOCSINCLASS(D,c)
# 5 prior[c] ← Nc/N
# 6 textc ← CONCATENATETEXTOFALLDOCSINCLASS(D c)
# 7 for each t ∈ V
# 8 do Tct ← COUNTTOKENSOFTERM(textc, t)
# 9 for each t ∈ V
# 10 do condprob[t][c] ← Tct+1/∑t′(Tct′+1)
# 11 return V, prior, condprob
#
# APPLYMULTINOMIALNB(C, V, prior, condprob, d)
# 1 W ← EXTRACTTOKENSFROMDOC(V, d)
# 2 for each c ∈ C
# 3 do score[c] ← log prior[c]
# 4 for each t ∈ W
# 5 do score[c] += log condprob[t][c]
# 6 return arg maxc∈C score[c]
# </pre>

# %% [markdown]
# ### DATA SETUP

# %% [markdown]
# I need to have different sets of documents one with categorized documents for training the algorithm and other with uncategorized documents for testing. For example, have a look at my sample text file in my dataset,

# %% [markdown]
# In 2014, BMW developed a prototype of street lights equipped with power sockets to charge electric cars, called Light and Charge. Two of these charging facilities were installed at BMW's headquarters in Munich.

# %% [markdown]
# ### PROJECT CODE

# %%
#import required libraries
import math 
import re

# %%
# Extracts all different words from the training documents.
def V_extract(D):
    v=list()
    for i in D:
        for word in re.compile('\w+').findall(open(i,"r").read().lower()):
            if word not in v:
                v.append(word)
    return v

# Concatenates all documents of same class in to a single string in lower case
def concat_txt(S,C):
    txt=''
    for j in range(1,C.__len__()):
        txt+=open(S[C[j]],"r").read().lower()+" "
    return txt

# Counts occurence of a word in a given string
def count_tokens(i,j):
    count=0
    for word in re.compile('\w+').findall(i):
        if word==j:
            count+=1
    return count

# %%
# Trains the algorithm based on the given data set
def Train_Multinomial_NB(C, D):
    v = v_extract(D)
    n = len(D)
    prior = dict()
    text = dict ()
    cond_prob = dict() 
    tot_count = 0
    b=dict()
    
    for i in D:
        for word in re.compile('\w+').findall(open(i,"r").read().lower()):
            if word in b:
                b[word]+=1
            else:
                b[word]=1            
    for i in v:
        tot_count = tot_count+b[i]
          
    for i in C.keys():
        nc = C[i][0] 
        prior[i] = nc/n
        #concatenates text of all documents in a class
        text[i] = concat_txt(D,C[i]) 
        test=dict()
        class_not_text=""
        for k in C.keys():
            if k != i:
                #concatebates text of all documents other than the current class
                class_not_text+=" "+concat_txt(D,C[k]) 
                
        class_not_count=0
        for j in v:
            class_not_count+=count_tokens(class_not_text,j)+1
        for j in v:
             #counts the occurence of a word in the text of current class
            count = count_tokens(text[i],j)
            # conditional probability of a word to be in the current class
            test[j] = (count+1)/(class_not_count-count_tokens(class_not_text,j)-1) 
        cond_prob[i]=test    
    return v, prior, cond_prob

# %%
# Application of the test document
def ApplyMultinomialNB(C, v, prior, cond_prob, D):
    w = re.compile('\w+').findall(open(D,"r").read().lower())
    score = dict()
    for i in C:
        try:
            score[i] = math.log(prior[i])
        except:
            continue
        
        for d in w:
            try:
                # As logarithm of a value between 0 and 1 is a negative number, values in score is negative  
                score[i] += math.log(cond_prob[i][d]) 
            except:
                continue
    print(score)
    return str(max(score,key=score.get))+":"+str(max(score.values()))

# %%
# Data preparation for the algorithm into appropriate data structures
import os
cwd=os.getcwd()+"\\Training_Dataset"
class_dir=os.listdir(cwd)
D=list()
C=dict()
total_count=0
for clas in class_dir:
    count=0
    cls_dir=os.listdir(cwd+"/"+clas)
    cls=list()
    cls.append(len(cls_dir))
    for i in range(len(cls_dir)):
       D.append(cwd+'\\'+clas+'\\'+cls_dir[i])
       cls.append(total_count) 
       total_count+=1
    C[clas]=cls
#print (C)

# D is a list of all documents of all classes with absolute path
# C is a dictionary where keys are the classes and the value is list. And that list contains number of documents related to the class in the 0th location and followed by the location of the documents in the list D.

# %%
v,prior,cond_prob=TrainMultinomialNB(C,D) 
print(v)
print(prior)
print(cond_prob)
# Out:
# ['a', 'car', 'or', 'automobile', 'is', 'wheeled', 'motor', 'vehicle', 'used', 'for', 'transportation', 'most', 'definitions', 'of', 'say', 'they', 'run', 'primarily', 'on', 'roads', 'seat', 'one', 'to', 'eight', 'people', 'have', 'four', 'tires', 'and', 'mainly', 'transport', 'rather', 'than', 'goods', '2', '3', 'cars', 'came', 'into', 'global', 'use', 'during', 'the', '20th', 'century', 'developed', 'economies', 'depend', 'them', 'year', '1886', 'regarded', 'as', 'birth', 'modern', 'when', 'german', 'inventor', 'karl', 'benz', 'built', 'his', 'patent', 'motorwagen', 'did', 'not', 'become', 'widely', 'available', 'until', 'early', 'first', 'that', 'was', 'accessible', 'masses', '1908', 'model', 't', 'an', 'american', 'manufactured', 'by', 'ford', 'company', 'were', 'rapidly', 'adopted', 'in', 'us', 'where', 'replaced', 'animal', 'drawn', 'carriages', 'carts', 'but', 'took', 'much', 'longer', 'be', 'accepted', 'western', 'europe', 'other', 'parts', 'world', 'this', 'week', 'best', 'talk', 'suzy', 'planning', 'driver', 'her', 'parents', 'across', 'mexico', 'rebuilt', 'vw', 'vanagon', 'we', 'know', 'won', 'need', 'any', 'stinkin', 'badges', 'are', 'there', 'tools', 'she', 'can', 'bring', 'along', 'increase', 'chances', 'completing', 'trip', '15', 'elsewhere', 'kathy', 's', 'mercedes', 'wipers', 'so', 'bad', 'kids', 'lean', 'out', 'window', 'play', 'spotter', 'whenever', 'it', 'rains', 'method', '1', 'backing', 'up', 'straight', 'line', 'conduct', '360', 'degree', 'check', 'place', 'your', 'right', 'foot', 'brake', 'put', 'left', 'hand', 'top', 'middle', 'steering', 'wheel', 'reverse', 'look', 'back', 'over', 'passenger', 'side', 'shoulder', 'ease', 'off', 'slowly', 'automobiles', 'marketed', 'under', 'brands', 'bmw', 'with', 'sub', 'm', 'performance', 'models', 'i', 'plug', 'electric', 'mini', 'rolls', 'royce', 'motorcycles', 'brand', 'motorrad', 'has', 'significant', 'motorsport', 'history', 'especially', 'touring', 'formula', 'sports', 'isle', 'man', 'tt', 'biju', 'stop', 'falling', 'asleep', 'at', '10', '00', 'pm', 'home', 'behind', 'ed', 'learned', 'he', 'shouldn', 'try', 'change', 'fluids', 'before', 'morning', 'coffee', 'tom', 'ray', 'been', 'called', 'lots', 'things', 'repeat', 'polite', 've', 'never', 'more', 'flummoxed', 'high', 'school', 'student', 'lydia', 'insistence', 'calling', 'sir', 'too', 'find', 'why', 'key', 'keeps', 'while', 'driving', 'suzanne', 'concerned', 'about', 'gas', 'fumes', 'emanating', 'from', 'woman', 'husband', 'life', 'named', 'tootsie', 'also', 'faith', 'trusty', 'subaru', 'little', 'less', 'reliable', 'since', 'drove', 'maine', 'alaska', 'these', 'replicas', 'general', 'appearance', 'like', 'original', 'their', 'bodies', 'often', 'made', 'fiberglass', 'mats', 'soaked', 'polyester', 'resin', 'instead', 'sheet', 'metal', 'ac', 'cobra', 'lotus', '7', 'particularly', 'popular', 'examples', 'manufacture', 'now', 'being', 'owned', 'caterham', 'who', 'bought', 'rights', 'founder', 'colin', 'chapman', '1973', 'component', 'continued', 'development', 'design', 'whereas', 'all', 'style', 'kit', 'costing', 'significantly', 'having', 'residual', 'values', 'war', 'ii', 'many', 'production', 'facilities', 'had', 'heavily', 'bombed', 'east', 'germany', 'seized', 'soviet', 'government', 'remaining', 'banned', 'allies', 'producing', 'ban', 'basic', 'secondhand', 'salvaged', 'equipment', 'make', 'pots', 'pans', 'later', 'expanding', 'kitchen', 'supplies', 'bicycles', '1947', 'granted', 'permission', 'resume', 'motorcycle', 'its', 'post', 'r24', 'released', '1948', 'still', 'forbidden', 'however', 'bristol', 'aeroplane', 'bac', 'england', 'based', 'pre', 'using', 'plans', 'taken', 'offices', 'resumed', '1952', '501', 'large', 'sedan', 'throughout', '1950s', 'expanded', 'range', 'sedans', 'coupes', 'convertibles', '1954', '502', 'v8', 'engine', 'provide', 'affordable', 'began', 'isetta', 'micro', 'licence', 'iso', '1955', 'two', 'years', '600', 'lengthened', 'version', '1959', 'larger', '700', 'coupe', 'debt', 'lo ...
# {'Car': 0.6666666666666666, 'Flower': 0.3333333333333333}
# {'Car': {'a': 0.04187082405345212, 'car': 0.03175646079719667, 'or': 0.010094360324775072, 'automobile': 0.002628120893561104, 'is': 0.02143172779496244, 'wheeled': 0.002190100744634253, 'motor': 0.0030661410424879547, 'vehicle': 0.006570302233902759, 'used': 0.0039447731755424065, 'for': 0.011666299801893022, 'transportation': 0.0015330705212439773, 'most': 0.0050493962678375415, 'definitions': 0.0008760402978537013, 'of': 0.03389830508474576, 'say': 0.0015330705212439773, 'they': 0.006145741878841089, 'run': 0.0028471309680245293, 'primarily': 0.0010950503723171265, 'on': 0.01249725937294453, 'roads': 0.002190100744634253, 'seat': 0.0017520805957074025, 'one': 0.003517256539898879, 'to': 0.03975265017667844, 'eight': 0.0008760402978537013, 'people': 0.007230499561787906, 'have': 0.007236842105263158, 'four': 0.002628120893561104, 'tires': 0.0010950503723171265, 'and': 0.04837271511368703, 'mainly': 0.0008762322015334064, 'transport': 0.0019710906701708277, 'rather': 0.0008760402978537013, 'than': 0.0032851511169513796, 'goods': 0.0010950503723171265, '2': 0.0006574621959237344, '3': 0.0010960105217010083, 'cars': 0.020805957074025404, 'came': 0.0010950503723171265, 'into': 0.004163014899211218, 'global': 0.001314060446780552, 'use': 0.004380201489268506, 'during': 0.0019723865877712033, 'the': 0.09869604316546762, '20th': 0.0017520805957074025, 'century': 0.0024091108190976785, 'developed': 0.0008760402978537013, 'economies': 0.000657030223390276, 'depend': 0.000657030223390276, 'them': 0.0028477546549835705, 'year': 0.0013166556945358788, '1886': 0.0008760402978537013, 'regarded': 0.0004380201489268506, 'as': 0.007936507936507936, 'birth': 0.00043830813061582295, 'modern': 0.0017520805957074025, 'when': 0.005257393209200438, 'german': 0.0010950503723171265, 'inventor': 0.0004380201489268506, 'karl': 0.0008760402978537013, 'benz': 0.0017520805957074025, 'built': 0.0032851511169513796, 'his': 0.0032851511169513796, 'patent': 0.000657030223390276, 'motorwagen': 0.000657030223390276, 'did': 0.000657030223390276, 'not': 0.003943044906900329, 'become': 0.0008764241893076249, 'widely': 0.0004381161007667032, 'available': 0.000657030223390276, 'until': 0.0013143483023001095, 'early': 0.002410694718387026, 'first': 0.005038335158817087, 'that': 0.012296881862099254, 'was': 0.010074463425317565, 'accessible': 0.0004380201489268506, 'masses': 0.0004380201489268506, '1908': 0.0004380201489268506, 'model': 0.002190100744634253, 't': 0.0035049288061336256, 'an': 0.005704256252742431, 'american': 0.0010950503723171265, 'manufactured': 0.000657030223390276, 'by': 0.01118421052631579, 'ford': 0.001314060446780552, 'company': 0.0015334063526834612, 'were': 0.005475251861585633, 'rapidly': 0.000657030223390276, 'adopted': 0.000657030223390276, 'in': 0.040856890459363956, 'us': 0.001314060446780552, 'where': 0.002190100744634253, 'replaced': 0.001314060446780552, 'animal': 0.0004380201489268506, 'drawn': 0.000657030223390276, 'carriages': 0.0004380201489268506, 'carts': 0.0004380201489268506, 'but': 0.004168494953927161, 'took': 0.0010950503723171265, 'much': 0.0010950503723171265, 'longer': 0.0004381161007667032, 'be': 0.006795265234546251, 'accepted': 0.000657030223390276, 'western': 0.0004380201489268506, 'europe': 0.0004380201489268506, 'other': 0.0041639272408503175, 'parts': 0.0019710906701708277, 'world': 0.0019758507135016466, 'this': 0.006369426751592357, 'week': 0.002628120893561104, 'best': 0.0028483786152497807, 'talk': 0.002628120893561104, 'suzy': 0.000657030223390276, 'planning': 0.0004380201489268506, 'driver': 0.0008760402978537013, 'her': 0.0026298487836949377, 'parents': 0.0004380201489268506, 'across': 0.0004380201489268506, 'mexico': 0.0004380201489268506, 'rebuilt': 0.000657030223390276, 'vw': 0.0010950503723171265, 'vanagon': 0.0004380201489268506, 'we': 0.0017520805957074025, 'know': 0.0004380201489268506, 'won': 0.0008760402978537013, 'need': 0.001314060446780552, 'any': 0.002190100744634253, 'stinkin': 0.0004380201489 ...

# %% [markdown]
# ### RESULTS

# %%
print(ApplyMultinomialNB(C,v,prior,cond_prob,"Test6.txt"))   
print(ApplyMultinomialNB(C,v,prior,cond_prob,"Test7.txt"))
# Out:
# {'Car': -29.182797822814237, 'Flower': -26.19175943466098}
# Flower:-26.19175943466098
# {'Car': -14.038936869298102, 'Flower': -17.982689324299066}
# Car:-14.038936869298102

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# Finally, I used Multinomial Naive Bayes classification technique. It uses Bayes Theorem to find the probability of the document to be in particular class or category. And this is based on analysis of the previous document set used for training the algorithm.

# %% [markdown]
# ### REFERENCES

# %% [markdown]
# https://nlp.stanford.edu/IR-book/pdf/13bayes.pdf
# http://scikit-learn.org/stable/modules/naive_bayes.html
# https://nlp.stanford.edu/IR-book/html/htmledition/naive-bayes-text-classification-1.html
# http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# https://www.analyticsvidhya.com/blog/2017/09/naive-bayes-explained/
# https://en.wikipedia.org/wiki/Naive_Bayes_classifier
# https://www.3pillarglobal.com/insights/document-classification-using-multinomial-naive-bayes-classifier
# http://sebastianraschka.com/Articles/2014_naive_bayes_1.html
